# %%
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
df = pd.read_csv("filtered_list.csv")
df
# Out:
#                                  Track URI  \
# 0     spotify:track:2D2lazsae9o1UoVPUAdxyT
# 1     spotify:track:2RvLlxea9woaqb2ZLgAmv7
# 2     spotify:track:53dtP2iUMvaF28JZcHnFuU
# 3     spotify:track:401qSkk4KOeBVld2aiCAoK
# 4     spotify:track:2hkcv7xQJgmLvCY3XSixjG
# ...                                    ...
# 1195  spotify:track:2jdAk8ATWIL3dwT47XpRfu
# 1196  spotify:track:4QlzkaRHtU8gAdwqjWmO8n
# 1197  spotify:track:3wlNmUeoHnM1jcOcXxC6qI
# 1198  spotify:track:3p428gAKm9dBoMjBVOIvVu
# 1199  spotify:track:1elGwF4VwkwglV4nCBPJtv
#
#                                              Track Name  \
# 0                                                    21
# 1                                                  emma
# 2                                               logical
# 3                                   Lovers to Strangers
# 4                                              Dussmann
# ...                                                 ...
# 1195                     Slow Dancing in a Burning Room
# 1196                                 Friday I'm In Love
# 1197                                          Rivendell
# 1198  I Can't Hear It Now (from the series Arcane Le...
# 1199                                    Now We Are Free
#
#                                          Artist Name(s)  Duration (ms)  \
# 0                                         Gracie Abrams         185172
# 1                                                Casper         195066
# 2                                        Olivia Rodrigo         231907
# 3                                           Chance Peña         174086
# 4                                              Betterov         217551
# ...                                                 ...            ...
# 1195                                         John Mayer         241946
# 1196                                           The Cure         215160
# 1197                                       Howard Shore         206026
# 1198                               Arcane;Freya Ridings         161040
# 1199  Hans Zimmer;Klaus Badelt;Lisa Gerrard;Gavin Gr...         254293
#
#       Popularity  Explicit     User  playlist year  release_year
# 0             31     False    Emily           2023          2020
# 1             40     False    Emily           2023          2023
# 2             71     False    Emily           2023          2023
# 3             52      True    Emily           2023          2023
# 4             45     False    Emily           2023          2022
# ...          ...       ...      ...            ...           ...
# 1195          78     False  William           2025          2006
# 1196          79     False  William           2025          1992
# 1197          56     False  William           2025          2001
# 1198          64     False  William           2025          2024
# 1199          67     False  William           2025          2000
#
# [1200 rows x 9 columns]

# %%
# add duration in minutes (float) and as mm:ss
df['Duration_min'] = (df['Duration (ms)'] / 60000).round(2)

def ms_to_mmss(ms):
    sec = int(ms // 1000)
    m = sec // 60
    s = sec % 60
    return f"{m}:{s:02d}"

df['Duration_mmss'] = df['Duration (ms)'].apply(ms_to_mmss)

# display a preview
df[['Track Name', 'Artist Name(s)', 'Duration (ms)', 'Duration_min', 'Duration_mmss']].head()
# Out:
#             Track Name  Artist Name(s)  Duration (ms)  Duration_min  \
# 0                   21   Gracie Abrams         185172          3.09
# 1                 emma          Casper         195066          3.25
# 2              logical  Olivia Rodrigo         231907          3.87
# 3  Lovers to Strangers     Chance Peña         174086          2.90
# 4             Dussmann        Betterov         217551          3.63
#
#   Duration_mmss
# 0          3:05
# 1          3:15
# 2          3:51
# 3          2:54
# 4          3:37

# %%
# Numeric columns
numeric_cols = df.select_dtypes(include='number').columns.tolist()

# Boolean columns (True / False)
bool_cols = df.select_dtypes(include='bool').columns.tolist()

# Combined selector options
stat_cols = numeric_cols + bool_cols

stat_cols
# Out:
# ['Duration (ms)',
#  'Popularity',
#  'playlist year',
#  'release_year',
#  'Duration_min',
#  'Explicit']

# %%
output = widgets.Output()

def user_stats_plot(column):
    output.clear_output(wait=True)

    with output:
        # Boolean column handling
        if column in bool_cols:
            stats = (
                df
                .assign(_bool_as_int=df[column].astype(int))
                .groupby('User')['_bool_as_int']
                .agg(
                    mean='mean',   # proportion explicit
                    sum='sum',     # count explicit
                    min='min',
                    max='max'
                )
            )

            display(stats)
        # Numeric column handling
        else:
            stats = (
                df
                .groupby('User')[column]
                .agg(['mean', 'median', 'min', 'max'])
            )

            display(stats)
        plt.tight_layout()
        plt.show()

# %%
column_selector = widgets.Dropdown(
    options=stat_cols,
    description='Column:'
)

column_selector.observe(
    lambda change: user_stats_plot(change['new']),
    names='value'
)

display(column_selector, output)

# Initial render
user_stats_plot(column_selector.value)
# Out:
# Dropdown(description='Column:', options=('Duration (ms)', 'Popularity', 'playlist year', 'release_year', 'Dura…
# Output()

# %%
import webbrowser
songs_per_user = 10

selected_songs = (
    df
    .groupby('User', group_keys=False)
    .apply(lambda x: x.sample(n=songs_per_user, random_state=None))
    .reset_index(drop=True)
)
len(selected_songs)
game_playlist = selected_songs.sample(frac=1).reset_index(drop=True)


current_index = 0

def play_next_song():
    global current_index

    if current_index >= len(game_playlist):
        print("🎉 Game over — no more songs!")
        return

    row = game_playlist.iloc[current_index]

    track_uri = row['Track URI']
    track_name = row['Track Name']
    artist = row['Artist Name(s)']
    selected_user = row['User']
    release_year = row['release_year']

    # Cross-check with original df
    matches = df[
        (df['Track Name'] == track_name) &
        (df['Artist Name(s)'] == artist)
    ]

    users_with_track = sorted(matches['User'].unique().tolist())
    playlist_years = sorted(matches['playlist year'].dropna().unique().tolist())

    print(f"🎵 Now playing ({current_index + 1}/{len(game_playlist)})")
    print(f"Track: {track_name}")
    print(f"Artist: {artist}")
    print(f"Release year: {release_year}")
    print(f"Playlist year(s): {playlist_years}")
    print(f"Appears in playlists of: {users_with_track}")
    print(f"Selected from: {selected_user}")

    webbrowser.open(track_uri)

    current_index += 1
# Out:
# C:\Users\willi\AppData\Local\Temp\ipykernel_7788\1944218852.py:7: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(n=songs_per_user, random_state=None))

# %%
game_playlist
# Out:
#                                Track URI  \
# 0   spotify:track:2mruPq4Gcx8tPpkQawsrbl
# 1   spotify:track:5ivmcr2ey37sIiZGlKu9IA
# 2   spotify:track:4lZ7OpzFPYJIWVgfuWU0zv
# 3   spotify:track:4or7DZfr1xrfurpJhleZa6
# 4   spotify:track:5nq0wConoTHndauu719R2I
# 5   spotify:track:7tCHpjktA50ihtkLz6bAnn
# 6   spotify:track:61nkMojCSJuXspIOWmo0vE
# 7   spotify:track:1nuYw5614RF5tm7Byrigw5
# 8   spotify:track:4kbkYbhWNiSJraySknB4hD
# 9   spotify:track:5E2JcyolDstvqZ0PNpT3pS
# 10  spotify:track:0SIs8JBctcihX2L1nbXZfU
# 11  spotify:track:78TUjr7fWQMPb0yINnOJSN
# 12  spotify:track:7mKkpSKp0Gba3aWSkcVvL2
# 13  spotify:track:5RX8T3EoTuXcybAxe6oPAw
# 14  spotify:track:3kXoKlD84c6OmIcOLfrfEs
# 15  spotify:track:2GxrNKugF82CnoRFbQfzPf
# 16  spotify:track:53dtP2iUMvaF28JZcHnFuU
# 17  spotify:track:2HiGtNatPUPfWK5EVjErOw
# 18  spotify:track:3D1vCe7Phmw2AGd0SAuFib
# 19  spotify:track:7jWNHuhGttkZmIVlxQ4Nh5
# 20  spotify:track:61nJplehv0WVUKMQX0pd8O
# 21  spotify:track:5BJUPXEuhz6jEFdvmEXdof
# 22  spotify:track:66YywMJbAgzQrGkFKjnSsK
# 23  spotify:track:1MsoH4Fz8O9PKbTW5SkXbJ
# 24  spotify:track:08p6O2CATs7HaOw3LuN6i3
# 25  spotify:track:1c39AwcrkN9srI7Az5662I
# 26  spotify:track:7mzPAftljnsFmU6131Pqcd
# 27  spotify:track:6R8MCJtqkqvRNG76Cswy1M
# 28  spotify:track:2ysCPFIglN1r2pHKAzLU53
# 29  spotify:track:3BouYneOiIcnpuswhcfjwf
# 30  spotify:track:65FOp8zFzwiIABbI8HGBLN
# 31  spotify:track:78M1wvMhGVpuMx7kLxLQ88
# 32  spotify:track:7fcIobA5JUkd90ad8y0cjO
# 33  spotify:track:4yNNFapUZM7aTElXE2JveQ
# 34  spotify:track:6Ixn21VEhC20fPcy2CDuIy
# 35  spotify:track:429IbFR4yp2J81CeTwF5iY
# 36  spotify:track:0EhPZsTp9WiXxgW2kpBZuJ
# 37  spotify:track:21SMupJDpMF1Hwzyhm0vQy
# 38  spotify:track:4zOzzuK5q0h2qkIVFEK3hn
# 39  spotify:track:3w0w2T288dec0mgeZZqoNN
#
#                                          Track Name  \
# 0                                           DXMINXS
# 1                                           Epilog?
# 2                                        Dies & Das
# 3                                           Geister
# 4            Ніч яка місячна (feat. Tember Blanche)
# 5   Ain't No Rest For The Wicked - Original Version
# 6        BLXXDY NXSE (feat. Scarlxrd & nascar aloe)
# 7                                           Luktelk
# 8                                            Baller
# 9                                              SUVs
# 10                                         The Mist
# 11                              Disparity By Design
# 12                                 Pa amb Oli I Sal
# 13                                      Cha Cha Cha
# 14                                        September
# 15                       i like the way you kiss me
# 16                                          logical
# 17                                     GEiSTESKRA$$
# 18                                 Schwertschlucken
# 19                                     Altbaudielen
# 20                                  Fly On the Wall
# 21                                   El Far del Sud
# 22                                  Ok Love You Bye
# 23                                        och i ach
# 24                                        Breakdown
# 25                                      NIGHT RIDER
# 26                                Tripping Over Air
# 27                      Duvet - Slowed Down Version
# 28                                   Kleine Tattoos
# 29                                  700 Main Street
# 30                                         про Київ
# 31                                       Бути тобою
# 32                                          Я вдома
# 33                                     Frozen Tears
# 34                                     DONNiE DARKO
# 35                                        Sweetness
# 36                            Dance With Night Wind
# 37                                            okay!
# 38                                    Count Funkula
# 39                                         CARNIVAL
#
#                                        Artist Name(s)  Duration (ms)  \
# 0                                    TWISTED;Scarlxrd         176913
# 1                                          Eden Bleak         187889
# 2                                  01099;Gustav;Zachi         140466
# 3                                          Eden Bleak         161298
# 4                                 mine;Tember Blanche         221007
# 5                                   Cage The Elephant         175493
# 6                         Jasiah;Scarlxrd;nascar aloe         187317
# 7                                      Silvester Belt         161142
# 8                                        Abor & Tynna         159493
# 9                                             Luciano         162173
# 10                                 Christopher Larkin          94526
# 11                                       Rise Against         228640
# 12                                            Blaumut         227120
# 13                                            Käärijä         175161
# 14                                 Earth, Wind & Fire         216022
# 15                                            Artemas         142514
# 16                                     Olivia Rodrigo         231907
# 17                            TJ_beastboy;dyzzy.earth         193000
# 18                                        Kind Kaputt         193020
# 19                                         Ivo Martin         150382
# 20                               Thousand Foot Krutch         242772
# 21                                      Sopa De Cabra         257146
# 22                                        Olivia Dean         154386
# 23                                  Sylwia Grzeszczak         181382
# 24                                        Yungmon;LEX         139937
# 25                                               Joji         127986
# 26                                      Aidan Bissett         182382
# 27                                                bôa         258507
# 28                                       Paula Engels         146973
# 29                                           DAT ADAM         243028
# 30                                     Tember Blanche         212288
# 31                                       Odyn v Kanoe         247238
# 32                                     Tember Blanche         178755
# 33                                            Luciano         208282
# 34                             TJ_beastboy;Kynda Gray         176500
# 35                                    Jimmy Eat World         220026
# 36                                      Akira Yamaoka         321760
# 37                                Replay Okay;Zsá Zsá         118583
# 38                                   Danny Baranowsky         198260
# 39  ¥$;Kanye West;Ty Dolla $ign;Rich The Kid;Playb...         264324
#
#     Popularity  Explicit     User  playlist year  release_year  Duration_min  \
# 0           36      True     Keke           2023          2022          2.95
# 1           14     False    Emily           2023          2022          3.13
# 2           58     False     Keke           2024          2022          2.34
# 3            3     False    Emily           2023          2022          2.69
# 4           15     False  William           2023          2023          3.68
# 5           66     False    Lewis           2023          2008          2.92
# 6           36      True     Keke           2023          2023          3.12
# 7            0     False  William           2024          2024          2.69
# 8           66     False    Emily           2025          2025          2.66
# 9           56     False     Keke           2024          2022          2.70
# 10          52     False    Lewis           2025          2025          1.58
# 11          41     False    Lewis           2024          2011          3.81
# 12          43     False  William           2023          2013          3.79
# 13          63     False  William           2023          2023          2.92
# 14          83     False    Lewis           2024          1978          3.60
# 15          81     False    Emily           2025          2024          2.38
# 16          71     False    Emily           2024          2023          3.87
# 17          40      True     Keke           2024          2020          3.22
# 18          15     False    Lewis           2024          2019          3.22
# 19          46     False    Emily           2024          2024          2.51
# 20          58     False    Lewis           2023          2012          4.05
# 21           0     False  William           2023          2002          4.29
# 22          83     False  William           2025          2019          2.57
# 23          59     False  William           2024          2024          3.02
# 24          32      True     Keke           2025          2021          2.33
# 25           1      True    Emily           2023          2022          2.13
# 26          59      True    Emily           2024          2022          3.04
# 27          54     False    Lewis           2025          2023          4.31
# 28          24     False    Emily           2025          2025          2.45
# 29          58     False     Keke           2025          2015          4.05
# 30          41     False  William           2023          2022          3.54
# 31          23     False  William           2024          2016          4.12
# 32          26     False  William           2023          2022          2.98
# 33          46     False     Keke           2024          2022          3.47
# 34          43      True     Keke           2024          2024          2.94
# 35          69     False    Lewis           2024          2001          3.67
# 36          41     False    Lewis           2024          2003          5.36
# 37          38     False    Emily           2025          2025          1.98
# 38          23     False    Lewis           2025          2025          3.30
# 39          10      True     Keke           2024          2024          4.41
#
#    Duration_mmss
# 0           2:56
# 1           3:07
# 2           2:20
# 3           2:41
# 4           3:41
# 5           2:55
# 6           3:07
# 7           2:41
# 8           2:39
# 9           2:42
# 10          1:34
# 11          3:48
# 12          3:47
# 13          2:55
# 14          3:36
# 15          2:22
# 16          3:51
# 17          3:13
# 18          3:13
# 19          2:30
# 20          4:02
# 21          4:17
# 22          2:34
# 23          3:01
# 24          2:19
# 25          2:07
# 26          3:02
# 27          4:18
# 28          2:26
# 29          4:03
# 30          3:32
# 31          4:07
# 32          2:58
# 33          3:28
# 34          2:56
# 35          3:40
# 36          5:21
# 37          1:58
# 38          3:18
# 39          4:24

# %%
play_next_song()
# Out:
# 🎵 Now playing (40/40)
# Track: CARNIVAL
# Artist: ¥$;Kanye West;Ty Dolla $ign;Rich The Kid;Playboi Carti
# Release year: 2024
# Playlist year(s): [2024]
# Appears in playlists of: ['Keke']
# Selected from: Keke
